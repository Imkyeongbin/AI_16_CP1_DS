# %%
import time, platform, sys
def finish_alarm():
    
    if platform.system() == 'Windows':
        import winsound
        for i in range(3):
            winsound.MessageBeep()
            time.sleep(2)
    elif platform.system() == 'Darwin':  # macOS
        import AppKit
        sound = AppKit.NSSound.alloc()
        sound.initWithContentsOfFile_byReference_('/System/Library/Sounds/Basso.aiff', True)
        sound.play()
    elif platform.system() == 'Linux':
        # 예시로 pygame 라이브러리를 사용하여 소리를 재생합니다.
        import pygame

        pygame.mixer.init()
        pygame.mixer.music.load('../alarm/alarm.wav')
        pygame.mixer.music.play()
    else:
        sys.stderr.write('Unsupported platform: %s' % platform.system())

# %%
# yolov5/runs/train의 exp 마지막 디렉토리에 있는 weights/best.pt를 구한다.
import os
def find_lastexp():
    dir_prefix = 'exp'
    max_dir_num = -1

    for dir_name in os.listdir('../yolov5/runs/train'):
        if dir_name.startswith(dir_prefix):
            try:
                dir_num = int(dir_name[len(dir_prefix):])
                if dir_num > max_dir_num:
                    max_dir_num = dir_num
            except:
                # exp'' 인 경우
                max_dir_num = 0

    # max_dir_num 값에 따라 max_dir_name을 대입한다.
    max_dir_name = dir_prefix + str(max_dir_num if max_dir_num != 0 else '')
    return max_dir_name

# %%
def detect(SOURCE):
    os.environ['KMP_DUPLICATE_LIB_OK']='True'

    max_dir_name = find_lastexp()

    # !python ../yolov5/detect.py --source $SOURCE --weights ../yolov5/runs/train/$max_dir_name/weights/best.pt

    finish_alarm()

# %%
#소스 선택
SOURCE = '../dataset/images/val'

detect(SOURCE)
# Out:
# detect: weights=['../yolov5/runs/train/exp12/weights/best.pt'], source=../dataset/images/val, data=..\yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=..\yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "torchvision>=0.8.1" not found, attempting AutoUpdate...
# WARNING: Ignoring invalid distribution -cipy (c:\users\scinn\.conda\envs\cp1\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\scinn\.conda\envs\cp1\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\scinn\.conda\envs\cp1\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\scinn\.conda\envs\cp1\lib\site-packages)
# ...
#
# ...
#
# ...
